# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaClaraRivas/Aulas_PA/blob/main/Exercicios_fluxogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios

# %% [markdown]
# ### 1) Identifique os dados de entrada, processamento e saída no algoritmo abaixo

# %% [markdown]
# * Receba Valor da peça (VALOR) Receba Quantidade de peças (QTDE) Entrada
# * Calcule o valor total da peça (VT) (VT = QTDE * VALOR) P
# * Mostre o seu valor total (VT) Saída

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2) Faça um algoritmo para “Calcular o estoque médio de uma peça”, sendo que

# %% [markdown]
# * ESTOQUEMEDIO = (QUANTIDADE_MINIMA + QUANTIDADE_MAXIMA) /2
# * QTDEMIN, QMAXIMA (Entrada)
# * ESTOQUEMEDIO = (QUANTIDADE_MINIMA + QUANTIDADE_MAXIMA) /2
# (Processamento)
# * ESTOQUEMEDIO (Saída)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3) Teste o algoritmo anterior com dados definidos por você.

# %%
qtdemin = float(input("Quantidade miníma da peça: "))
qmaxima = float(input("Quantidade maxima da peça: "))
estoquemedio = (qtdemin * qmaxima)/2
print("O estoque médio é",estoquemedio)
# Out:
# Quantidade miníma: 9
# Quantidade maxima: 7
# O estoque médio é 31.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercícios em Phyton

# %% [markdown]
# Exercicio 1:

# %%
dolar = float(input("Digite a cotação do dolar: "))
valor = float(input("Digite so valor que gostaria de converter em dólar: "))
resultado = valor/dolar
print("O resultado é", resultado)
# Out:
# Digite a cotação do dolar: 5
# Digite so valor que gostaria de converter em dólar: 25
# O resultado é 5.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# teste de mesa

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# fluxograma

# %% [markdown]
# Exercicio 2:

# %%
n1 = float(input("Digite um numero: "))
n2 = float(input("Digite um numero: "))
n3 = float(input("Digite um numero: "))
n4 = float(input("Digite um numero: "))
area1 = n1 * n1
area2 = n2 * n2
area3 = n3 * n3
area4 = n4 * n4
resultado = area1 + area2 + area3 + area4
print("A soma do quadrado dos valores antes mencionados é:",resultado )
# Out:
# Digite um numero: 2
# Digite um numero: 4
# Digite um numero: 5
# Digite um numero: 6
# A soma do quadrado dos valores antes mencionados é: 81.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercicio 3:

# %%
preco = float(input("Preço unitário da peça: "))
qntade = float(input("Quantidade de peças vendidas: "))
comissa = float(input("Valor em % da comissão: "))
pre = preco * qntade
resultado = pre * comissa
final = resultado/100
print("O valor da comissão é: ",final )
print(pre,"reais em vendas")
# Out:
# Preço unitário da peça: 40
# Quantidade de peças vendidas: 60
# Valor em % da comissão: 5
# O valor da comissão é:  120.0
# 2400.0 reais em vendas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercicio 4:

# %%
carro = float(input("Preço de fábrica do carro "))
imposto = float(input("valor em % dos impostos "))
distribuicao = float(input("valor em % da distribuição "))
impost = imposto/100
distri = distribuicao/100
impostos = carro * impost
menos = carro + impostos
distribuicoes = menos * distri
consumidor = distribuicoes + menos
resultado = consumidor * 1.000
print("O valor do carro para o consumidor será: ",resultado)
# Out:
# Preço de fábrica do carro 200
# valor em % dos impostos 4
# valor em % da distribuição 2
# O valor do carro para o consumidor será:  212.16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercicio 5:

# %% [markdown]
# conversão em horas:

# %%
hora = float(input("Número de Horas: "))
minutos = float(input("Número de Minutos: "))
conversao = minutos/60
hora_minuto = hora + conversao
print("O valor convertido é: ",hora_minuto)
# Out:
# Número de Horas: 12
# Número de Minutos: 30
# O valor convertido é:  12.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# converção de horas e minutos para segundos:

# %%
hora = float(input("Número de Horas: "))
minutos = float(input("Número de Minutos: "))
minuto_segundo = minutos * 60
hora_minuto = hora * 60
hora_segundo = hora_minuto * 60
segundos = hora_segundo + minuto_segundo
print("O valor convergido para segundos é: ",segundos)
# Out:
# Número de Horas: 3
# Número de Minutos: 45
# O valor convergido para segundos é:  13500.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercicio 6:

# %%
hora = float(input("Número de Horas extras trabalhadas: " ))
minutos = float(input("Número de Minutos extras trabalhados: " ))
salario = float(input("Ganho por hora:" ))
empresa = float(input("Ganho a mais por horas extras trabalhadas em %: "))
min = minutos/60
horas = min + hora
ganho = horas * salario
porcento = empresa/100
calculando_porcentagem = porcento * ganho
resultado = calculando_porcentagem + ganho
print("Ganharei",resultado)
# Out:
# Número de Horas extras trabalhadas: 5
# Número de Minutos extras trabalhados: 0
# Ganho por hora:5
# Ganho a mais por horas extras trabalhadas em %: 5
# Ganharei 26.25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercicio 7:

# %%
km = float(input("Quilômetros a percorrer: " ))
carro = float(input("Quantos litros seu carro consome por km: " ))
preco = float(input("Preço Médio da Gasolina: " ))
litros = km/carro
ida = litros * preco
volta = ida * 2
print("Você gastará apenas na ida a média de: ",ida)
print("Você gastará  na ida e volta a média de: ",volta)
# Out:
# Quilômetros a percorrer: 900
# Quantos km seu carro consome por litro: 2
# Preço Médio da Gasolina: 5
# Você gastará apenas na ida a média de:  2250.0
# Você gastará  na ida e volta a média de:  4500.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercicio 8:

# %%
max = float(input("Velocidade Máxima da estrada em km/h: " ))
km = float(input("Percurso percorrido em km: " ))
hora = float(input("Horas gastas: " ))
minutos = float(input("Minutos gastos: " ))
min = minutos/60
h = min + hora
vm = km/h
resultado = round(vm, 2)
print("A velocidade média é:",resultado, "km/h")
# Out:
# Velocidade Máxima da estrada em km/h: 90
# Percurso percorrido em km: 76
# Horas gastas: 3
# Minutos gastos: 0
# A velocidade média é: 25.33 km/h

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
